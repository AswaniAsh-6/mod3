# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('mpg.csv')
print(df)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model_year  origin   name
# 0         False   False  False
# 1         False   False  False
# ...

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
missing=(df[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'model_year', 'origin', 'name']]==0).sum()
print(missing)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
a=df.head(10)
a
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.shape
# Out:
# (398, 9)

# %%
df.size
# Out:
# 3582

# %%
df.ndim
# Out:
# 2

# %%
df.sum(axis=0)
# Out:
# mpg                                                        9358.8
# cylinders                                                    2171
# displacement                                              76983.5
# horsepower                                                40952.0
# weight                                                    1182229
# acceleration                                               6196.1
# model_year                                                  30252
# origin          usausausausausausausausausausausausausausajapa...
# name            chevrolet chevelle malibubuick skylark 320plym...
# dtype: object

# %%
df.sum(axis=1)
# Out:
# 0      4049.0
# 1      4312.5
# 2      4011.0
# 3      3993.0
# 4      3996.5
#         ...
# 393    3144.6
# 394    2433.6
# 395    2643.6
# 396    2956.6
# 397    3057.4
# Length: 398, dtype: float64

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#      weight  origin                       name   mpg  model_year  horsepower  \
# 0      3504     usa  chevrolet chevelle malibu  18.0          70       130.0
# 1      3693     usa          buick skylark 320  15.0          70       165.0
# 2      3436     usa         plymouth satellite  18.0          70       150.0
# 3      3433     usa              amc rebel sst  16.0          70       150.0
# 4      3449     usa                ford torino  17.0          70       140.0
# ..      ...     ...                        ...   ...         ...         ...
# 393    2790     usa            ford mustang gl  27.0          82        86.0
# 394    2130  europe                  vw pickup  44.0          82        52.0
# 395    2295     usa              dodge rampage  32.0          82        84.0
# 396    2625     usa                ford ranger  28.0          82        79.0
# 397    2720     usa                 chevy s-10  31.0          82        82.0
#
#      displacement  cylinders  acceleration
# ...

# %%
df1=pd.DataFrame(df,columns=['acceleration','name'])
print(df1)
# Out:
#      acceleration                       name
# 0            12.0  chevrolet chevelle malibu
# 1            11.5          buick skylark 320
# 2            11.0         plymouth satellite
# 3            12.0              amc rebel sst
# 4            10.5                ford torino
# ..            ...                        ...
# 393          15.6            ford mustang gl
# 394          24.6                  vw pickup
# 395          11.6              dodge rampage
# 396          18.6                ford ranger
# 397          19.4                 chevy s-10
#
# [398 rows x 2 columns]

# %%
d=pd.RangeIndex(398)
d
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df3=df.reindex(index=d[0:10],columns=list(df.columns)+['new_col'])
df3.loc[d[0]:d[6],'new_col']=1
print(df3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name  new_col
# 0          70    usa  chevrolet chevelle malibu      1.0
# 1          70    usa          buick skylark 320      1.0
# 2          70    usa         plymouth satellite      1.0
# ...

# %%
df3.dropna()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
#
#    model_year origin                       name  new_col
# 0          70    usa  chevrolet chevelle malibu      1.0
# 1          70    usa          buick skylark 320      1.0
# 2          70    usa         plymouth satellite      1.0
# 3          70    usa              amc rebel sst      1.0
# 4          70    usa                ford torino      1.0
# 5          70    usa           ford galaxie 500      1.0
# ...

# %%
df3.fillna(value=3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name  new_col
# 0          70    usa  chevrolet chevelle malibu      1.0
# 1          70    usa          buick skylark 320      1.0
# 2          70    usa         plymouth satellite      1.0
# ...

# %%
df3.mean()
# Out:
# mpg               15.6
# cylinders          8.0
# displacement     374.9
# horsepower       178.3
# weight          3879.7
# acceleration      10.3
# model_year        70.0
# new_col            1.0
# dtype: float64

# %%
df4=[df[:20],df[20:100],df[100:]]
df4
# Out:
# [     mpg  cylinders  displacement  horsepower  weight  acceleration  \
#  0   18.0          8         307.0       130.0    3504          12.0
#  1   15.0          8         350.0       165.0    3693          11.5
#  2   18.0          8         318.0       150.0    3436          11.0
#  3   16.0          8         304.0       150.0    3433          12.0
#  4   17.0          8         302.0       140.0    3449          10.5
#  5   15.0          8         429.0       198.0    4341          10.0
#  6   14.0          8         454.0       220.0    4354           9.0
#  7   14.0          8         440.0       215.0    4312           8.5
#  8   14.0          8         455.0       225.0    4425          10.0
#  9   15.0          8         390.0       190.0    3850           8.5
#  10  15.0          8         383.0       170.0    3563          10.0
#  11  14.0          8         340.0       160.0    3609           8.0
#  12  15.0          8         400.0       150.0    3761           9.5
# ...

# %%
pd.concat(df4)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
import csv

# %%
a = df['mpg'].tolist()
b = df['cylinders'].tolist()
c = df['weight'].tolist()
d = df['origin'].tolist()
e = df['name'].tolist()

# %%
plt.plot(d,b)
plt.xlabel('origin')
plt.ylabel('cylinders')
plt.title('mpg')
plt.show()

# %%
plt.bar(d,b,color='pink')
plt.xlabel('origin')
plt.ylabel('cylinders')
plt.title('mpg')
plt.show()

# %%
plt.hist(a,bins=[0,25,50,75,100],color='y')
plt.xlabel('mpg')
plt.ylabel('bins')
plt.title('mpg')
plt.show()

# %%
from matplotlib import style
plt.scatter(d,c,color='pink')
plt.xlabel('origin')
plt.ylabel('weight')
plt.title('mpg-scatter')
plt.show()

# %%
plt.plot([],[],label='a',linewidth=5)
plt.plot([],[],label='b',linewidth=5)
plt.plot([],[],label='c',linewidth=5)
plt.stackplot(a,b,c,colors=['y','r','w'])
plt.show()

# %%
plt.pie(b)
plt.show()

# %%
sns.relplot(x=a,y=b,data=df)

# %%
sns.relplot(x=a,y=b,data=df,hue=d)

# %%
sns.relplot(x=a,y=b,data=df,kind='line')

# %%
sns.catplot(x=d,y=a,data=df,kind='violin')

# %%
sns.catplot(x=d,y=a,data=df,kind='boxen')

# %%
x=sns.FacetGrid(df,col="origin")
x.map(plt.hist,"cylinders")

# %%
y=sns.PairGrid(df)
y.map(plt.scatter)

# %%
sns.set(style="white",color_codes=True)
sns.boxplot(x="cylinders",y="mpg",data=df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
sns.set(style="white",color_codes=True)
sns.boxplot(x="cylinders",y="mpg",data=df)
sns.despine(offset=10,trim=True)

# %%
sns.distplot(df['mpg'],kde=False,bins=25)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='mpg'>

# %%
sns.jointplot(x=a,y=b,data=df,kind='reg')

# %%
sns.kdeplot(df['mpg'])
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
sns.rugplot(df['mpg'])
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.set_style('white')
plt.figure(figsize=(8,4))
sns.set_context('paper',font_scale=1.4)
sns.jointplot(x="cylinders",y="mpg",data=df,kind='reg')
sns.despine(left=False,bottom=False)

# %%
sns.barplot(x="cylinders",y="mpg",data=df,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
sns.countplot(x='origin',data=df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %%
plt.figure(figsize=(14,9))
sns.set_style('darkgrid')
sns.boxplot(x="cylinders",y="mpg",data=df)
plt.legend(loc=0)
# Out:
# No handles with labels found to put in legend.

# %%
sns.violinplot(x="cylinders",y="mpg",data=df,split=True)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x="cylinders",y="mpg",data=df,jitter=True,dodge=True)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
sns.violinplot(x="cylinders",y="mpg",data=df)
sns.swarmplot(x="cylinders",y="mpg",data=df,color='k')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 19.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
plt.figure(figsize=(8,6))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x="cylinders",y="mpg",data=df,palette='seismic')
plt.legend(loc=0)
# Out:
# No handles with labels found to put in legend.

# %%
e=sns.FacetGrid(df,col='origin',col_wrap=5,height=1.5)
e.map(plt.plot,'mpg','cylinders',marker='.')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)
