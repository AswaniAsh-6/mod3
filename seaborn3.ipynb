# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=sns.load_dataset('planets')
sns.relplot(x="year",y="distance",data=a)

# %%
sns.relplot(x="year",y="distance",hue="number",data=a)

# %%
b=sns.load_dataset("titanic")
sns.relplot(x="age",y="fare",data=b,kind="line")

# %%
sns.catplot(x="class",y="age",kind="violin",data=b)

# %%
sns.catplot(x="class",y="age",kind="boxen",data=b)

# %%
from scipy import stats

# %%
c=np.random.normal(loc=7,size=150,scale=3)
sns.displot(c)

# %%
a=sns.load_dataset("planets")
b=sns.FacetGrid(a,col="method")
b.map(plt.hist,"year")

# %%
a=sns.load_dataset("planets")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="darkgrid")
a=sns.load_dataset("titanic")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="white",color_codes=True)
a=sns.load_dataset("titanic")
sns.boxplot(x="class",y="fare",data=a)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sns.set(style="white",color_codes=True)
a=sns.load_dataset("titanic")
sns.boxplot(x="class",y="fare",data=a)
sns.despine(offset=10,trim=True)

# %%
a=sns.load_dataset("titanic")
sns.distplot(a['fare'],kde=False,bins=25)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare'>

# %%
sns.jointplot(x='age',y='pclass',data=a,kind='reg')

# %%
sns.kdeplot(a['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.pairplot(a)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
b=sns.load_dataset('planets')
sns.rugplot(b['mass'])
# Out:
# <AxesSubplot:xlabel='mass'>

# %%
sns.set_style('white')
plt.figure(figsize=(8,4))
sns.set_context('paper',font_scale=1.4)
sns.jointplot(x='age',y='pclass',data=a,kind='reg')
sns.despine(left=False,bottom=False)

# %%
sns.barplot(x='number',y='mass',data=b,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='number', ylabel='mass'>

# %%
sns.countplot(x='number',data=b)
# Out:
# <AxesSubplot:xlabel='number', ylabel='count'>

# %%
plt.figure(figsize=(14,9))
sns.set_style('darkgrid')
sns.boxplot(x='class',y='fare',data=a,hue='sex')
plt.legend(loc=0)

# %%
sns.violinplot(x='class',y='fare',data=a,hue='sex',split=True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
#strip plot
plt.figure(figsize=(8,5))
sns.stripplot(x='class',y='fare',data=a,jitter=True,hue='sex',dodge=True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sns.violinplot(x='class',y='fare',data=a)
sns.swarmplot(x='class',y='fare',data=a,color='k')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 71.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 86.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
plt.figure(figsize=(8,6))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='class',y='fare',data=a,hue='sex',palette='seismic')
plt.legend(loc=0)

# %%
d=sns.load_dataset("planets")
e=sns.FacetGrid(d,col='number',col_wrap=5,height=1.5)
e.map(plt.plot,'mass','distance',marker='.')
